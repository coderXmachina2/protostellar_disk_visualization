# %%
#visualizing protostellar disks from 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

circumstellar_disks = pd.read_csv("data/circumstellardisks.csv")
df = pd.DataFrame(circumstellar_disks)
print(circumstellar_disks)
# Out:
#                      Object Category Spec_Type R_band_mag  Distance_pc  \
# 0    2MASSI J1628137-243139       TT       NaN       17.7       140.00
# 1                    49 Cet   Debris        A1        5.6        59.00
# 2                    61 Vir   Debris       G7V        4.2         8.50
# 3                    99 Her   Debris     F7+K4        4.7        15.60
# 4      [MR81] H alpha 17 NE       TT       M2e       16.9       150.00
# 5                    AA Tau       TT        M0       11.8       140.00
# 6                    AB Aur      HAe       A0e        7.1       144.00
# 7                 alpha CrB   Debris      A0 V        2.2        23.00
# 8                  AS 205 A       TT        K0       12.8       128.00
# 9                  AS 205 B       TT     K7+M0         14       128.00
# 10                   AS 209       TT        K5       10.4       121.00
# 11                   ASR 41       TT       NaN        NaN       316.00
# ...

# %%
prot_disk_cat = df.Category.unique() #unique types of protostellar disks
print("Unique Protostellar Disk Types: " + str(prot_disk_cat) + "\n")
print("Counts of Types:")
print(data['Category'].value_counts())
#Count Missing Values
print("Number of missing values:")
types = ["Debris", "TT", "UC", "YSO", "HAe", "Trans","YSO?", "wTT","PPN", "HBe"]
#Make it properly
# Out:
# Unique Protostellar Disk Types: ['TT' 'Debris' 'HAe' 'YSO?' 'YSO' 'Trans' 'HBe' nan 'PPN' 'UC' 'wTT']
#
# Counts of Types:
# Debris    96
# TT        72
# UC        37
# YSO       22
# HAe       17
# Trans      3
# YSO?       1
# wTT        1
# PPN        1
# HBe        1
# Name: Category, dtype: int64
# Number of missing values:

# %%
#Attach visualization of what each Disk Means

# %%
fig = plt.figure()
plt.bar(types, data['Category'].value_counts())
fig.suptitle('Count of unique Categories of protostellar disks', fontsize=14)
plt.xlabel('Type of protostellar disk', fontsize=14)
plt.ylabel('Count', fontsize=14)
#plt.yticks(np.arange(0, a, step=5))
plt.grid()
plt.show()

# %%
prot_disk_spec_type = df.Spec_Type.unique()
print("Spectral Type Bins:\n" + str(prot_disk_spec_type) + "\n") #just take out the first 
print("Counts of Types:")
print(df['Spec_Type'].value_counts())

types = ["O", "B", "A", "F", "G", "K","M"] #sort
# Out:
# Spectral Type Bins:
# [nan 'A1' 'G7V' 'F7+K4' 'M2e' 'M0' 'A0e' 'A0 V' 'K0' 'K7+M0' 'K5' 'M1'
#  'A3V' 'A5' 'A5 III' 'A1V' 'K7' 'M4' 'F2' 'K6' 'K4' 'M0 V' 'K5.5' 'K2'
#  'M2.5' 'F2 V' 'M5' 'A3' 'M3' 'F1' 'A0' 'M1.5' 'A9Ve' 'B9' 'F8' 'F8 V'
#  'F5' 'G2' 'F5 V' 'F3' 'F3/5' 'F3V' 'F6V' 'G1V' 'A2IV' 'F4Ve' 'F5 IV-V'
#  'A5IV' 'B9.5' 'G2V' 'F6' 'A8' 'G7' 'A2 IV' 'A0V' 'F5V' 'A1e' 'K0Ve' 'F0'
#  'A2V' 'B8 V' 'B8.5' 'A0IVp' 'A1Va' 'F1III' 'B2Ve' 'G6' 'K2V' 'A7V' 'A0.5'
#  'K6V' 'B8' 'K1' 'G8' 'A1Vp' 'A8III' 'A5?' 'B7.5' 'M0.5' 'K1IV' 'A0p'
#  'M5.5' 'A2e' 'A3e' 'M4.5' 'G8?' 'G6-K3' 'M3e' 'K1 IV' 'G3' 'G8 V' 'M2 Ve'
#  'G5 V' 'B8-A7']
#
# Counts of Types:
# M0         16
# K5         14
# K7         12
# A0         10
# M4          5
# F2          5
# M3          5
# M1          5
# F5          4
# A1V         4
# G2V         4
# A0V         4
# A5          4
# K1          4
# F3V         4
# A3          3
# A2IV        3
# A0 V        3
# F5V         3
# A5IV        3
# G2          3
# ...

# %%
disk_magnitude = df[['R_band_mag']]
print(disk_magnitude)

#Find number of missing values
# Out:
#     R_band_mag
# 0         17.7
# 1          5.6
# 2          4.2
# 3          4.7
# 4         16.9
# 5         11.8
# 6          7.1
# 7          2.2
# 8         12.8
# 9           14
# 10        10.4
# 11         NaN
# 12         8.9
# 13           2
# 14         3.9
# 15         2.9
# 16         2.3
# 17        12.2
# 18        11.1
# 19         NaN
# 20         NaN
# 21        12.3
# 22        14.5
# 23        16.8
# 24         8.9
# 25         NaN
# 26        12.5
# 27        11.4
# 28         NaN
# 29        11.8
# ..         ...
# 223       11.3
# 224       11.1
# 225        4.8
# 226       10.2
# 227       11.2
# 228       12.8
# 229        NaN
# 230       14.2
# 231       11.7
# 232       14.4
# 233       11.9
# 234        3.5
# 235       11.4
# 236       10.9
# 237         11
# 238        NaN
# 239         10
# 240       11.2
# 241       12.5
# 242        9.6
# 243        NaN
# 244       14.4
# 245        0.1
# 246         12
# 247        NaN
# 248        NaN
# ...
